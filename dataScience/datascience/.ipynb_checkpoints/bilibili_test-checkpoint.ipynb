# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('douban.xlsx')

# %%
df.head()
# Out:
#        名字      投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港

# %%
df.tail()
# Out:
#                                                       名字  投票人数  \
# 38733                                              神学院 S  46.0
# 38734                                              1935年  57.0
# 38735                                               血溅画屏  95.0
# 38736                                             魔窟中的幻想  51.0
# 38737  列宁格勒围困之星火战役 Блокада: Фильм 2: Ленинградский ме...  32.0
#
#                    类型    产地                 上映时间  时长    年代   评分 首映地点
# 38733           Adult    法国  1905-06-05 00:00:00  58  1983  8.6   美国
# 38734           喜剧/歌舞    美国  1935-03-15 00:00:00  98  1935  7.6   美国
# 38735  剧情/悬疑/犯罪/武侠/古装  中国大陆  1905-06-08 00:00:00  91  1986  7.1   美国
# 38736        惊悚/恐怖/儿童  中国大陆  1905-06-08 00:00:00  78  1986  8.0   美国
# 38737           剧情/战争    苏联  1905-05-30 00:00:00  97  1977  6.6   美国

# %%
df.iloc[5]
# Out:
# 名字                   泰坦尼克号
# 投票人数                 157074
# 类型                 剧情/爱情/灾难
# 产地                       美国
# 上映时间    2012-04-10 00:00:00
# 时长                      194
# 年代                     2012
# 评分                      9.4
# 首映地点                   中国大陆
# Name: 5, dtype: object

# %%
df[:5]
# Out:
#        名字      投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港

# %%
df.loc[:5]
# Out:
#        名字      投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
# 5  泰坦尼克号   157074.0  剧情/爱情/灾难    美国  2012-04-10 00:00:00  194  2012  9.4
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港
# 5    中国大陆

# %%
dic = {'名字':'逃跑地球','投票人数':12345,'类型':'科幻','产地':'中国','上映时间':'2019-10-10 00:00:00','时长':124,'年代':2019,'评分':8.4,'首映地点':'中国'}
s = pd.Series(dic)
s.name = 38738

# %%
s
# Out:
# 名字                     逃跑地球
# 投票人数                  12345
# 类型                       科幻
# 产地                       中国
# 上映时间    2019-10-10 00:00:00
# 时长                      124
# 年代                     2019
# 评分                      8.4
# 首映地点                     中国
# Name: 38738, dtype: object

# %%
df =df.append(s)

# %%
df.tail()
# Out:
#                                                       名字     投票人数  \
# 38734                                              1935年     57.0
# 38735                                               血溅画屏     95.0
# 38736                                             魔窟中的幻想     51.0
# 38737  列宁格勒围困之星火战役 Блокада: Фильм 2: Ленинградский ме...     32.0
# 38738                                               逃跑地球  12345.0
#
#                    类型    产地                 上映时间   时长    年代   评分 首映地点
# 38734           喜剧/歌舞    美国  1935-03-15 00:00:00   98  1935  7.6   美国
# 38735  剧情/悬疑/犯罪/武侠/古装  中国大陆  1905-06-08 00:00:00   91  1986  7.1   美国
# 38736        惊悚/恐怖/儿童  中国大陆  1905-06-08 00:00:00   78  1986  8.0   美国
# 38737           剧情/战争    苏联  1905-05-30 00:00:00   97  1977  6.6   美国
# 38738              科幻    中国  2019-10-10 00:00:00  124  2019  8.4   中国

# %%
df.drop([38738])
# Out:
#                                                       名字      投票人数  \
# 0                                                 肖申克的救赎  692795.0
# 1                                                   控方证人   42995.0
# 2                                                  美丽人生   327855.0
# 3                                                   阿甘正传  580897.0
# 4                                                   霸王别姬  478523.0
# 5                                                 泰坦尼克号   157074.0
# 6                                                 辛德勒的名单  306904.0
# 7                  新世纪福音战士剧场版：Air/真心为你 新世紀エヴァンゲリオン劇場版 Ai   24355.0
# 8                         银魂完结篇：直到永远的万事屋 劇場版 銀魂 完結篇 万事屋よ   21513.0
# 9                                               这个杀手不太冷   662552.0
# 10                                                 灿烂人生    16807.0
# 11                                                 疯狂动物城  284652.0
# 12                              福音战士新剧场版：破 ヱヴァンゲリヲン新劇場版：   32524.0
# ...

# %%
df[df['名字'].isnull()]
# Out:
#         名字    投票人数           类型    产地                 上映时间   时长    年代   评分  \
# 231    NaN   144.0       纪录片/音乐    韩国  2011-02-02 00:00:00   90  2011  9.7
# 361    NaN    80.0           短片    其他  1905-05-17 00:00:00    4  1964  5.7
# 369    NaN  5315.0           剧情    日本  2004-07-10 00:00:00  111  2004  7.5
# 372    NaN   263.0        短片/音乐    英国  1998-06-30 00:00:00   34  1998  9.2
# 374    NaN    47.0           短片    其他  1905-05-17 00:00:00    3  1964  6.7
# 375    NaN  1193.0        短片/音乐    法国  1905-07-01 00:00:00   10  2010  7.7
# 411    NaN    32.0           短片    其他  1905-05-17 00:00:00    3  1964  7.0
# 432    NaN  1081.0  剧情/动作/惊悚/犯罪    美国  2016-02-26 00:00:00  115  2016  6.0
# 441    NaN   213.0           恐怖    美国  2007-03-06 00:00:00   83  2007  3.2
# 448    NaN   110.0          纪录片    荷兰  2002-04-19 00:00:00   48  2000  9.3
# 454    NaN   122.0       纪录片/音乐    英国  1992-10-27 00:00:00  120  1992  9.4
# ...

# %%
df[df['投票人数']<0]
# Out:
#                                           名字   投票人数     类型    产地  \
# 19777                               皇家大贼 皇家大  -80.0  剧情/犯罪  中国香港
# 19786  日本的垃圾去中国大陆 にっぽんの“ゴミ” 大陆へ渡る ～中国式リサイクル錬  -80.0    纪录片    日本
# 19797                                    女教徒 -118.0     剧情    法国
#
#                       上映时间   时长    年代   评分 首映地点
# 19777  1985-05-31 00:00:00   60  1985  6.3   美国
# 19786  1905-06-26 00:00:00   60  2004  7.9   美国
# 19797  1966-05-06 00:00:00  135  1966  7.8   美国

# %%
df = df[df['投票人数']>0]

# %%
df= df[df['投票人数']%1 ==0]

# %%
len(df)
# Out:
# 38732

# %%
df1 = df.fillna('未知电影')

# %%
df1[df1['名字'].isnull()]
# Out:
# Empty DataFrame
# Columns: [名字, 投票人数, 类型, 产地, 上映时间, 时长, 年代, 评分, 首映地点]
# Index: []

# %%
len(df)
# Out:
# 38169

# %%
df2 = df.dropna()

# %%
len(df2)
# Out:
# 38169

# %%
df.dropna(inplace=True)

# %%
df.to_excel('movie_data.xlsx')

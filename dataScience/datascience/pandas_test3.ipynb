# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('movie_data2.xlsx')

# %%
df[:5]
# Out:
#        名字    投票人数        类型    产地                 上映时间   时长    年代   评分    首映地点
# 0  肖申克的救赎  692795     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6  多伦多电影节
# 1    控方证人   42995  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5      美国
# 2   美丽人生   327855  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5     意大利
# 3    阿甘正传  580897     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4   洛杉矶首映
# 4    霸王别姬  478523  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4      香港

# %%
data = pd.DataFrame(np.arange(12).reshape(4,3),index=[['a','a','b','b'],[1,2,1,2]],columns=[['A','A','B'],['z','c','x']])
data
# Out:
#      A       B
#      z   c   x
# a 1  0   1   2
#   2  3   4   5
# b 1  6   7   8
#   2  9  10  11

# %%
data.columns.names=['row1','row2']
data.index.names=['clo1','clo2']

# %%
data
# Out:
# row1       A       B
# row2       z   c   x
# clo1 clo2
# a    1     0   1   2
#      2     3   4   5
# b    1     6   7   8
#      2     9  10  11

# %%
data.swaplevel('clo1','clo2')
# Out:
# row1       A       B
# row2       z   c   x
# clo2 clo1
# 1    a     0   1   2
# 2    a     3   4   5
# 1    b     6   7   8
# 2    b     9  10  11

# %%
df = df.set_index(['产地','年代'])
df
# Out:
#                                                           名字    投票人数  \
# 产地   年代
# 美国   1994                                             肖申克的救赎  692795
#      1957                                               控方证人   42995
# 意大利  1997                                              美丽人生   327855
# 美国   1994                                               阿甘正传  580897
# 中国大陆 1993                                               霸王别姬  478523
# 美国   2012                                             泰坦尼克号   157074
#      1993                                             辛德勒的名单  306904
# 日本   1997              新世纪福音战士剧场版：Air/真心为你 新世紀エヴァンゲリオン劇場版 Ai   24355
#      2013                     银魂完结篇：直到永远的万事屋 劇場版 銀魂 完結篇 万事屋よ   21513
# 法国   1994                                           这个杀手不太冷   662552
# 意大利  2003                                              灿烂人生    16807
# 美国   2016                                              疯狂动物城  284652
# ...

# %%
df.index[0]
# Out:
# ('美国', 1994)

# %%
df.loc['美国']
# Out:
#               名字    投票人数              类型                 上映时间   时长   评分  \
# 年代
# 1994      肖申克的救赎  692795           剧情/犯罪  1994-09-10 00:00:00  142  9.6
# 1957        控方证人   42995        剧情/悬疑/犯罪  1957-12-17 00:00:00  116  9.5
# 1994        阿甘正传  580897           剧情/爱情  1994-06-23 00:00:00  142  9.4
# 2012      泰坦尼克号   157074        剧情/爱情/灾难  2012-04-10 00:00:00  194  9.4
# 1993      辛德勒的名单  306904        剧情/历史/战争  1993-11-30 00:00:00  195  9.4
# 2016       疯狂动物城  284652     喜剧/动作/动画/冒险  2016-03-04 00:00:00  109  9.3
# 2009         海豚湾  159302             纪录片  2009-07-31 00:00:00   92  9.3
# 2008     机器人总动员   421734  喜剧/爱情/科幻/动画/冒险  2008-06-27 00:00:00   98  9.3
# 1957        十二怒汉  134949              剧情  1957-04-01 00:00:00   96  9.3
# 2008     旅行到宇宙边缘   10044             纪录片  2008-11-07 00:00:00   90  9.3
# 2009     暴力云与送子鹳   75567     喜剧/动画/短片/奇幻  2009-05-29 00:00:00    6  9.2
# 1931        城市之光   31105        剧情/喜剧/爱情  1931-01-30 00:00:00   87  9.2
# ...

# %%
df = df.swaplevel('产地','年代')

# %%
df[:5]
# Out:
#                名字    投票人数        类型                 上映时间   时长   评分    首映地点
# 年代   产地
# 1994 美国    肖申克的救赎  692795     剧情/犯罪  1994-09-10 00:00:00  142  9.6  多伦多电影节
# 1957 美国      控方证人   42995  剧情/悬疑/犯罪  1957-12-17 00:00:00  116  9.5      美国
# 1997 意大利    美丽人生   327855  剧情/喜剧/爱情  1997-12-20 00:00:00  116  9.5     意大利
# 1994 美国      阿甘正传  580897     剧情/爱情  1994-06-23 00:00:00  142  9.4   洛杉矶首映
# 1993 中国大陆    霸王别姬  478523  剧情/爱情/同性  1993-01-01 00:00:00  171  9.4      香港

# %%
df = df.reset_index()

# %%
df[:4]
# Out:
#      年代   产地      名字    投票人数        类型                 上映时间   时长   评分    首映地点
# 0  1994   美国  肖申克的救赎  692795     剧情/犯罪  1994-09-10 00:00:00  142  9.6  多伦多电影节
# 1  1957   美国    控方证人   42995  剧情/悬疑/犯罪  1957-12-17 00:00:00  116  9.5      美国
# 2  1997  意大利   美丽人生   327855  剧情/喜剧/爱情  1997-12-20 00:00:00  116  9.5     意大利
# 3  1994   美国    阿甘正传  580897     剧情/爱情  1994-06-23 00:00:00  142  9.4   洛杉矶首映

# %%
data = df[:5]

# %%
data.T
# Out:
#                         0                    1                    2  \
# 年代                   1994                 1957                 1997
# 产地                     美国                   美国                  意大利
# 名字                 肖申克的救赎                 控方证人                美丽人生
# 投票人数               692795                42995               327855
# 类型                  剧情/犯罪             剧情/悬疑/犯罪             剧情/喜剧/爱情
# 上映时间  1994-09-10 00:00:00  1957-12-17 00:00:00  1997-12-20 00:00:00
# 时长                    142                  116                  116
# 评分                    9.6                  9.5                  9.5
# 首映地点               多伦多电影节                   美国                  意大利
#
#                         3                    4
# 年代                   1994                 1993
# 产地                     美国                 中国大陆
# 名字                   阿甘正传                 霸王别姬
# 投票人数               580897               478523
# 类型                  剧情/爱情             剧情/爱情/同性
# ...

# %%
data.stack()
# Out:
# 0  年代                     1994
#    产地                       美国
#    名字                   肖申克的救赎
#    投票人数                 692795
#    类型                    剧情/犯罪
#    上映时间    1994-09-10 00:00:00
#    时长                      142
#    评分                      9.6
#    首映地点                 多伦多电影节
# 1  年代                     1957
#    产地                       美国
#    名字                     控方证人
#    投票人数                  42995
#    类型                 剧情/悬疑/犯罪
#    上映时间    1957-12-17 00:00:00
#    时长                      116
#    评分                      9.5
#    首映地点                     美国
# 2  年代                     1997
#    产地                      意大利
#    名字                    美丽人生
#    投票人数                 327855
#    类型                 剧情/喜剧/爱情
#    上映时间    1997-12-20 00:00:00
#    时长                      116
#    评分                      9.5
#    首映地点                    意大利
# 3  年代                     1994
#    产地                       美国
#    名字                     阿甘正传
# ...

# %%
data.stack().unstack()
# Out:
#      年代    产地      名字    投票人数        类型                 上映时间   时长   评分    首映地点
# 0  1994    美国  肖申克的救赎  692795     剧情/犯罪  1994-09-10 00:00:00  142  9.6  多伦多电影节
# 1  1957    美国    控方证人   42995  剧情/悬疑/犯罪  1957-12-17 00:00:00  116  9.5      美国
# 2  1997   意大利   美丽人生   327855  剧情/喜剧/爱情  1997-12-20 00:00:00  116  9.5     意大利
# 3  1994    美国    阿甘正传  580897     剧情/爱情  1994-06-23 00:00:00  142  9.4   洛杉矶首映
# 4  1993  中国大陆    霸王别姬  478523  剧情/爱情/同性  1993-01-01 00:00:00  171  9.4      香港

# %%
group = df.groupby(df['产地'])
type(group)
# Out:
# pandas.core.groupby.groupby.DataFrameGroupBy

# %%
group.mean()
# Out:
#                年代          投票人数          时长        评分
# 产地
# 中国台湾  1999.009709   8474.864078   87.257282  7.066667
# 中国大陆  2013.260847  10895.461741   81.427294  6.065711
# 中国香港  1991.100316   8167.446159   88.541214  6.474114
# 丹麦    1999.090909   1993.858586   88.101010  7.245960
# 俄罗斯   1984.899371   1019.134172   95.918239  7.554507
# 其他    1998.761334   1591.494007   87.100573  7.237467
# 加拿大   2002.461964   1915.304288   80.109267  6.733610
# 印度    2005.974790   3210.843137  121.016807  6.872269
# 墨西哥   1992.815126   1173.218487   91.840336  7.087395
# 巴西    1999.871287   3536.000000   87.811881  7.262376
# 德国    1996.062984   2597.851744   92.062016  7.198062
# 意大利   1985.503338   3340.740988  104.008011  7.179306
# 日本    1999.907092   3565.876585   84.705428  7.194572
# 比利时   1999.496403   1230.122302   82.352518  7.217986
# 法国    1991.757016   3628.402842   89.901599  7.239432
# 波兰    1987.027624    881.640884   80.734807  7.441989
# ...

# %%
group.sum()
# Out:
#             年代       投票人数       时长       评分
# 产地
# 中国台湾   1235388    5237466    53925   4367.2
# 中国大陆   7656431   41435441   309668  23067.9
# 中国香港   5676627   23285389   252431  18457.7
# 丹麦      395820     394784    17444   1434.7
# 俄罗斯     946797     486127    45753   3603.5
# 其他     3835623    3054077   167146  13888.7
# 加拿大    1447780    1384765    57919   4868.4
# 印度      716133    1146271    43203   2453.4
# 墨西哥     237145     139613    10929    843.4
# 巴西      201987     357136     8869    733.5
# 德国     2059937    2680983    95008   7428.4
# 意大利    1487142    2502215    77902   5377.3
# 日本    10095531   18000545   427593  36318.2
# 比利时     277930     170987    11447   1003.3
# 法国     5606796   10213954   253073  20379.0
# 波兰      359652     159577    14613   1347.0
# 泰国      590684    1564881    26002   1796.1
# 澳大利亚    600896    1415713    25549   2093.4
# 瑞典      381491     290077    17898   1423.3
# 美国    23884926  101805710  1081401  83188.8
# ...

# %%
df['评分'].groupby(df['年代']).mean()
# Out:
# 年代
# 1888     7.950000
# 1890     4.800000
# 1892     7.500000
# 1894     6.633333
# 1895     7.575000
# 1896     7.037500
# 1897     6.633333
# 1898     7.450000
# 1899     6.900000
# 1900     7.228571
# 1901     7.250000
# 1902     7.483333
# 1903     6.968750
# 1904     7.212500
# 1905     6.820000
# 1906     7.342857
# 1907     7.020000
# 1908     7.150000
# 1909     7.560000
# 1910     6.940000
# 1911     7.375000
# 1912     7.920000
# 1913     6.862500
# 1914     6.473077
# 1915     7.260000
# 1916     7.758333
# 1917     7.075000
# 1918     7.200000
# 1919     7.490000
# 1920     7.492857
#            ...
# 1988     7.265729
# 1989     7.210687
# 1990     7.149109
# 1991     7.154634
# 1992     7.223678
# 1993     7.195692
# 1994     7.262348
# 1995     7.289366
# 1996     7.258801
# 1997     7.330168
# 1998     7.238302
# 1999     7.188000
# 2000     7.134063
# 2001     7.110145
# 2002     7.069778
# 2003     7.137750
# 2004     7.031366
# 2005     7.030008
# ...

# %%
df['年代'] = df['年代'].astype('str')

# %%
df.groupby(df['产地']).mean()
# Out:
#               投票人数          时长        评分
# 产地
# 中国台湾   8474.864078   87.257282  7.066667
# 中国大陆  10895.461741   81.427294  6.065711
# 中国香港   8167.446159   88.541214  6.474114
# 丹麦     1993.858586   88.101010  7.245960
# 俄罗斯    1019.134172   95.918239  7.554507
# 其他     1591.494007   87.100573  7.237467
# 加拿大    1915.304288   80.109267  6.733610
# 印度     3210.843137  121.016807  6.872269
# 墨西哥    1173.218487   91.840336  7.087395
# 巴西     3536.000000   87.811881  7.262376
# 德国     2597.851744   92.062016  7.198062
# 意大利    3340.740988  104.008011  7.179306
# 日本     3565.876585   84.705428  7.194572
# 比利时    1230.122302   82.352518  7.217986
# 法国     3628.402842   89.901599  7.239432
# 波兰      881.640884   80.734807  7.441989
# 泰国     5322.724490   88.442177  6.109184
# 澳大利亚   4719.043333   85.163333  6.978000
# 瑞典     1510.817708   93.218750  7.413021
# 美国     8501.520668   90.304885  6.946873
# 英国     4797.089790   88.343592  7.526937
# 荷兰      934.425806   75.387097  7.190323
# ...

# %%
df.groupby([df['产地'],df['年代']]).mean()
# Out:
#                    投票人数          时长        评分
# 产地   年代
# 中国台湾 1963    121.000000  113.000000  6.400000
#      1965    153.666667  105.000000  6.800000
#      1966     51.000000   60.000000  7.900000
#      1967   4444.000000  112.000000  8.000000
#      1968     89.000000   83.000000  7.400000
#      1969     91.000000   86.333333  7.400000
#      1970    992.166667  108.666667  7.266667
#      1971     51.000000  102.666667  6.933333
#      1972    338.000000   90.500000  7.500000
#      1973    980.600000  101.600000  7.280000
#      1974    116.428571   98.857143  6.771429
#      1975    246.000000   82.111111  6.611111
#      1976    289.909091   74.363636  6.336364
#      1977    220.125000   83.250000  6.525000
#      1978    261.800000   75.800000  6.800000
#      1979    492.937500   88.000000  6.956250
#      1980    244.444444   84.333333  7.222222
#      1981    414.300000   81.700000  7.140000
#      1982    885.571429   86.714286  6.942857
# ...

# %%
df['评分'].groupby([df['产地'],df['年代']]).mean()
# Out:
# 产地    年代
# 中国台湾  1963    6.400000
#       1965    6.800000
#       1966    7.900000
#       1967    8.000000
#       1968    7.400000
#       1969    7.400000
#       1970    7.266667
#       1971    6.933333
#       1972    7.500000
#       1973    7.280000
#       1974    6.771429
#       1975    6.611111
#       1976    6.336364
#       1977    6.525000
#       1978    6.800000
#       1979    6.956250
#       1980    7.222222
#       1981    7.140000
#       1982    6.942857
#       1983    7.750000
#       1984    7.410000
#       1985    7.314286
#       1986    7.418182
#       1987    7.550000
#       1988    6.877778
#       1989    7.857143
#       1990    6.900000
#       1991    7.100000
#       1992    7.600000
#       1993    6.840000
#                 ...
# 韩国    1986    6.600000
#       1987    5.700000
#       1989    7.950000
#       1990    7.350000
#       1991    6.100000
#       1992    6.850000
#       1993    7.460000
#       1994    6.666667
# ...

# %%
df['等级评分'] = pd.cut(df['评分'],[0,3,5,7,9,10],labels=['E','D','C','B','A'])

# %%
df[:5]
# Out:
#      年代    产地      名字    投票人数        类型                 上映时间   时长   评分  \
# 0  1994    美国  肖申克的救赎  692795     剧情/犯罪  1994-09-10 00:00:00  142  9.6
# 1  1957    美国    控方证人   42995  剧情/悬疑/犯罪  1957-12-17 00:00:00  116  9.5
# 2  1997   意大利   美丽人生   327855  剧情/喜剧/爱情  1997-12-20 00:00:00  116  9.5
# 3  1994    美国    阿甘正传  580897     剧情/爱情  1994-06-23 00:00:00  142  9.4
# 4  1993  中国大陆    霸王别姬  478523  剧情/爱情/同性  1993-01-01 00:00:00  171  9.4
#
#      首映地点 等级评分
# 0  多伦多电影节    A
# 1      美国    A
# 2     意大利    A
# 3   洛杉矶首映    A
# 4      香港    A

# %%
bings = np.percentile(df['投票人数'],[0,20,40,60,80,100])

# %%
df['热门程度'] = pd.cut(df['投票人数'],bings,labels=['E','D','C','B','A'])

# %%
df[:5]
# Out:
#      年代    产地      名字    投票人数        类型                 上映时间   时长   评分  \
# 0  1994    美国  肖申克的救赎  692795     剧情/犯罪  1994-09-10 00:00:00  142  9.6
# 1  1957    美国    控方证人   42995  剧情/悬疑/犯罪  1957-12-17 00:00:00  116  9.5
# 2  1997   意大利   美丽人生   327855  剧情/喜剧/爱情  1997-12-20 00:00:00  116  9.5
# 3  1994    美国    阿甘正传  580897     剧情/爱情  1994-06-23 00:00:00  142  9.4
# 4  1993  中国大陆    霸王别姬  478523  剧情/爱情/同性  1993-01-01 00:00:00  171  9.4
#
#      首映地点 等级评分 热门程度
# 0  多伦多电影节    A    A
# 1      美国    A    A
# 2     意大利    A    A
# 3   洛杉矶首映    A    A
# 4      香港    A    A

# %%
df[(df.热门程度=='A')&(df.等级评分=='E')]
# Out:
#          年代    产地            名字   投票人数           类型                 上映时间   时长  \
# 655    2011  中国大陆            B区   5187     剧情/惊悚/恐怖  2011-06-03 00:00:00   89
# 4376   2014  中国大陆            怖偶   4867        悬疑/惊悚  2014-05-07 00:00:00   88
# 5413   2011  中国大陆          床下有人   4309        悬疑/惊悚  2011-10-14 00:00:00  100
# 6802   2013  中国大陆          帝国秘符   4351        动作/冒险  2013-09-18 00:00:00   93
# 8232   2011  中国大陆            飞天   4764           剧情  2011-07-01 00:00:00  115
# 8406   2014  中国大陆          分手达人   3937        喜剧/爱情  2014-06-06 00:00:00   90
# 9601   2012  中国大陆          孤岛惊魂   2982     悬疑/惊悚/恐怖  2013-01-26 00:00:00   93
# 10512  2013  中国大陆       海天盛宴·韦口   3788           情色  2013-10-12 00:00:00   88
# 16797  2013  中国大陆          孪生密码   6390        动作/悬疑  2013-11-08 00:00:00   96
# 21528  2010    日本            拳皇   6329     动作/科幻/冒险  2012-10-12 00:00:00   93
# 22700  2013  中国大陆            闪魂   3119        惊悚/犯罪  2014-02-21 00:00:00   94
# ...

# %%
df[(df.热门程度=='E')&(df.等级评分=='A')]
# Out:
#          年代    产地                                 名字  投票人数           类型  \
# 456    2015    美国                               神秘电影    45           音乐
# 587    2011    英国                             BBC喜剧音    38     喜剧/音乐/歌舞
# 642    2003    美国                               神秘电影    38       纪录片/音乐
# 686    2014    英国                               神秘电影    63      音乐/舞台艺术
# 698    2008    英国                               神秘电影    52          纪录片
# 844    2007    美国                               神秘电影    69       纪录片/运动
# 925    2012  澳大利亚                               神秘电影    33          纪录片
# 979    2014    日本  JOJO的奇妙冒险 特别见面会 Walk Like Crusade    36          纪录片
# 1081   2002    美国                               神秘电影    58           音乐
# 1107   2001    美国                               神秘电影    60           音乐
# 1110   2001    美国                               神秘电影    76       科幻/纪录片
# 1140   2002    英国                               神秘电影    41           短片
# ...

# %%
df.to_excel('movie_data3.xlsx')

# %%
df_usa = df[df['产地']=='美国']
df_china = df[df['产地']=='中国大陆']
df_china.append(df_usa)
# Out:
#          年代    产地            名字    投票人数           类型                 上映时间  \
# 4      1993  中国大陆          霸王别姬  478523     剧情/爱情/同性  1993-01-01 00:00:00
# 21     1961  中国大陆          大闹天宫   74881        动画/奇幻  1905-05-14 00:00:00
# 29     2015  中国大陆          穹顶之下   51113          纪录片  2015-02-28 00:00:00
# 38     1982  中国大陆            茶馆   10678        剧情/历史  1905-06-04 00:00:00
# 45     1988  中国大陆           山水情   10781        动画/短片  1905-06-10 00:00:00
# 49     2016  中国大陆   “人权卫士”的人权纪录     109          纪录片  2016-03-13 00:00:00
# 62     2014  中国大陆           0.5    2825           爱情  2014-09-12 00:00:00
# 67     2000  中国大陆          鬼子来了  180738        剧情/战争  2000-05-12 00:00:00
# 119    2008  中国大陆  11度青春之《李雷和韩梅    9583           短片  2010-10-21 00:00:00
# 132    1992  中国大陆        12只蚊子和    1231        动画/短片  1905-06-14 00:00:00
# 150    2016  中国大陆       我们的精神角落    8821        剧情/短片  2016-02-16 00:00:00
# 156    2010  中国大陆           小胖妞    8814     动作/动画/短片  2010-12-01 00:00:00
# ...

# %%
df1 = df[:10]
df2 = df[100:120]
df3 = df[200:210]

# %%
df4 = pd.concat([df1,df2,df3],axis=0)

# %%
df4
# Out:
#        年代    产地                                     名字    投票人数  \
# 0    1994    美国                                 肖申克的救赎  692795
# 1    1957    美国                                   控方证人   42995
# 2    1997   意大利                                  美丽人生   327855
# 3    1994    美国                                   阿甘正传  580897
# 4    1993  中国大陆                                   霸王别姬  478523
# 5    2012    美国                                 泰坦尼克号   157074
# 6    1993    美国                                 辛德勒的名单  306904
# 7    1997    日本  新世纪福音战士剧场版：Air/真心为你 新世紀エヴァンゲリオン劇場版 Ai   24355
# 8    2013    日本         银魂完结篇：直到永远的万事屋 劇場版 銀魂 完結篇 万事屋よ   21513
# 9    1994    法国                               这个杀手不太冷   662552
# 100  1993    韩国                                    101     146
# 101  1995    英国                                     10     186
# 102  2013    韩国                                     素媛  114819
# 103  2003    美国                             101忠狗续集：伦敦     924
# ...

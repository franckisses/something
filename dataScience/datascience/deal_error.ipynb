# %% [markdown]
# # 缺失值的处理

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data.csv',encoding='ANSI')
df
# Out:
#         编号    股票代码  股票名称                 公司名称   省份    城市           收入  \
# 0        1       1  平安银行           平安银行股份有限公司  深圳市   罗湖区     10578600
# 1        2       2   万科A           万科企业股份有限公司  深圳市   盐田区  24289711.03
# 2        3       4  国农科技       深圳中国农大科技股份有限公司  深圳市   南山区     13860.58
# 3        4       5  世纪星源         深圳世纪星源股份有限公司  深圳市   罗湖区     53092.22
# 4        5       6  深振业A      深圳市振业(集团)股份有限公司  深圳市   罗湖区    295945.02
# 5        6       7   全新好         深圳市全新好股份有限公司  深圳市   福田区       3964.4
# 6        7       8  神州高铁         神州高铁技术股份有限公司  北京市   海淀区    233093.22
# 7        8       9  中国宝安         中国宝安集团股份有限公司  深圳市   罗湖区    702351.12
# 8        9      10  美丽生态         深圳美丽生态股份有限公司  深圳市   宝安区     75788.57
# 9       10      11  深物业A    深圳市物业发展(集团)股份有限公司  深圳市   罗湖区    290469.07
# 10      11      12   南玻A         中国南玻集团股份有限公司  深圳市   南山区   1087940.07
# 11      12      14  沙河股份           沙河实业股份有限公司  深圳市   南山区      51314.1
# ...

# %% [markdown]
# ### `判断缺失值`

# %%
#df[df['行业'].notnull()][:1]  #查找行业中没有缺失的值的第一行
df[df['行业'].isnull()]  #查找行业中的缺失值第一个
# Out:
#         编号  股票代码  股票名称               公司名称   省份     城市          收入         利润  \
# 28      29    33   新都退       深圳新都酒店股份有限公司  NaN     广东         NaN        NaN
# 465    466  1965  招商公路  招商局公路网络科技控股股份有限公司  北京市    北京市   534066.43   336819.5
# 1315  1316  2864  盘龙药业     陕西盘龙药业集团股份有限公司  NaN     陕西    37679.16     4371.9
# 1349  1350  2900   哈三联      哈尔滨三联药业股份有限公司  NaN    黑龙江   114883.03   18107.55
# 1350  1351  2901  大博医疗       大博医疗科技股份有限公司  NaN     福建    59401.46   29555.63
# 1351  1352  2902  铭普光磁       东莞铭普光磁股份有限公司  NaN     广东    151010.3    8035.78
# 1352  1353  2903  宇环数控       宇环数控机床股份有限公司  NaN     湖南    25025.88    7897.98
# 1353  1354  2905  金逸影视     广州金逸影视传媒股份有限公司  NaN     广东   219101.01   21153.11
# 1354  1355  2906  华阳集团      惠州市华阳集团股份有限公司  NaN     广东    416584.8   28005.04
# 1355  1356  2907  华森制药       重庆华森制药股份有限公司  NaN     重庆    59209.54   11198.75
# 1356  1357  2908  德生科技       广东德生科技股份有限公司  NaN     广东    42682.18    5752.06
# ...

# %% [markdown]
# ## `填充缺失值`

# %%
df['行业'].fillna('未知',inplace=True)  #使用未知填充了空值。然后并且替换

# %%
df[df['行业'].isnull()]
# Out:
# Empty DataFrame
# Columns: [编号, 股票代码, 股票名称, 公司名称, 省份, 城市, 收入, 利润, 员工人数, 上市时间, 行业, 产品类型, 主营业务]
# Index: []

# %%
#df = df.fillna['未知参数']  #这样的写法会将所有的有空值的列都填充  #谨慎使用

# %% [markdown]
# ## `删除缺失值`

# %% [markdown]
# ###    `df.dropna()参数
#      how=‘all’ 删除全为空的行或者列
#      inplace=True 覆盖之前的数据
#      axis=0 选择行或者列`
#         `

# %%
len(df)
# Out:
# 3573

# %%
#df.dropna() #将所有的空值删除   不建议使用

# %% [markdown]
# ## `异常值的处理`

# %% [markdown]
# #### 异常值，在数据中不合理的一些数据。又称为离群点，例如年龄大于1000岁。为负数的。体重为1吨的等#例如投票的人数有小数的数据

# %%
df[df.收入<"0"]
# Out:
#         编号    股票代码 股票名称          公司名称  省份  城市  收入  利润 员工人数       上市时间  行业  \
# 1757  1758  300372  欣泰退  丹东欣泰电气股份有限公司  --  辽宁  --  --  371  2014/1/27  --
#
#      产品类型                               主营业务
# 1757   --  节能型输变电设备和无功补偿装置等电网性能优化设备的开发、生产及销售

# %% [markdown]
# ## `数据保存`

# %%
df.to_excel('newdata.xlsx')
